# %%
import sys
from pathlib import Path

HERE = Path.cwd()
PROJECT_ROOT = HERE.parent
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.api.database import db

# %%
task_id = "033d9440-4a25-45e4-916f-04f6e5f88107"
db.get_task_details(task_id)
# Out:
# {'user_id': 1882628381,
#  'summary': 'پرداخت قسط بانک تجارت',
#  'dtstart': datetime.datetime(2026, 5, 3, 3, 30),
#  'dtend': None,
#  'next_date': datetime.datetime(2026, 6, 3, 3, 30),
#  'exdate': None,
#  'rxdate': None,
#  'is_recurrent': True,
#  'rrule': 'FREQ=MONTHLY;INTERVAL=1',
#  'rrule_human': 'هر ۳۰ روز',
#  'description': 'وام ۲۰۰ تومنی بانک تجارت',
#  'completed': False,
#  'notified': False,
#  'id': '033d9440-4a25-45e4-916f-04f6e5f88107'}

# %%
import os
from zoneinfo import ZoneInfo
import datetime
from jdatetime import datetime as jdatetime
TIMEZONE = os.getenv("TIMEZONE")
DEFAULT_LOCAL_TZ = ZoneInfo(TIMEZONE)
DEFAULT_STORAGE_TZ = datetime.timezone.utc

# %%
timezone.end_of_day()
# Out:
# datetime.datetime(2026, 5, 11, 0, 0)

# %%
timezone.now().replace(tzinfo=None)
# Out:
# datetime.datetime(2026, 5, 10, 15, 43, 27, 323925)

# %%
jdatetime.now().strftime('%Y-%m-%dT%H:%M')
# Out:
# '1405-02-12T21:21'
